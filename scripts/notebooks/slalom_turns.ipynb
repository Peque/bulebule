# %% [markdown]
# # Slalom turns

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot


pyplot.style.use('seaborn')

# %%
from trajectory import Maze
from trajectory import RobotPhysics
from trajectory import Simulator
from trajectory import pi


classic = Maze(cell=0.18, post=0.012)
half = Maze(cell=0.09, post=0.006)

bulebule = RobotPhysics(
    mass=0.110,
    moment_of_inertia=(0.110 * 0.05 ** 2) / 2,
    width=0.085,
    wheels_separation=0.065,
    max_angular_velocity=20,
)

simulate = Simulator(robot=bulebule, maze=classic, time_period=0.00001)

# %%
i = bulebule.moment_of_inertia
m = bulebule.mass
s = bulebule.wheels_separation
pi = 3.1415

pi * i / (s * m)
# Out:
# 0.060413461538461555

# %% [markdown]
# ## Static turns

# %%
profile = simulate.inplace(angle=pi)
profile.plot_forces()

# %% [markdown]
# ## Search turn

# %%
profile = simulate.slalom(
    entry=(0, -.5, 0),
    exit=(.5, 0, pi/2),
    radius=0.04921,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.042
# Turn completed in 0.256 seconds
# Linear velocity: 0.473
# Finished at (0.09000, -0.01700)
# Parameters: {0.01700, 0.01700, 0.04921, 0.06042, 0.00037, xxx}

# %% [markdown]
# ## 90º turn

# %%
profile = simulate.slalom(
    entry=(0, -.5, 0),
    exit=(.5, 0, pi/2),
    radius=0.13,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.021
# Turn completed in 0.323 seconds
# Linear velocity: 0.769
# Finished at (0.09000, 0.06272)
# Parameters: {-0.06272, -0.06272, 0.13000, 0.06042, 0.12727, xxx}

# %%
profile.plot_forces()

# %%
profile.profile['angular_velocity'].plot()

# %% [markdown]
# ## 180º turn

# %%
profile = simulate.slalom(
    entry=(0, -.5, 0),
    exit=(0, .5, pi),
    radius=0.08882,
    shift=(-0.045, 0),
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.015
# Turn completed in 0.508 seconds
# Linear velocity: 0.635
# Finished at (-0.04500, 0.08999)
# Parameters: {-0.04499, -0.04500, 0.08882, 0.06042, 0.20211, xxx}

# %% [markdown]
# ## Turn to 45º

# %%
profile = simulate.slalom(
    entry=(0, -.5, 0),
    exit=(.5, 0, pi/4),
    radius=0.10,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.013
# Turn completed in 0.182 seconds
# Linear velocity: 0.674
# Finished at (0.04507, -0.04493)
# Parameters: {-0.06374, 0.06354, 0.10000, 0.06042, 0.00161, xxx}

# %%
.09 - (.18 * .4)
# Out:
# 0.018000000000000002

# %%
-0.06374 + 0.018
# Out:
# -0.04574

# %%
profile = simulate.slalom(
    entry=(0, -.4, 0),
    exit=(.5, 0, pi/4),
    radius=0.10,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.012
# Turn completed in 0.182 seconds
# Linear velocity: 0.674
# Finished at (0.06307, -0.02693)
# Parameters: {-0.04574, 0.03808, 0.10000, 0.06042, 0.00161, xxx}

# %% [markdown]
# ## Turn to 135º

# %%
profile = simulate.slalom(
    entry=(0, -.5, 0),
    exit=(0, .5, 3/4*pi),
    radius=0.08,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.011
# Turn completed in 0.385 seconds
# Linear velocity: 0.603
# Finished at (0.02576, 0.06424)
# Parameters: {-0.03813, 0.03642, 0.08000, 0.06042, 0.11157, xxx}

# %% [markdown]
# ## Turn diagonal 90º

# %%
profile = simulate.slalom(
    entry=(0, -.5, pi/4),
    exit=(0, .5, 3/4*pi),
    radius=0.065,
)
profile.describe()
profile.plot_trajectory()
# Out:
# Distance to post: 0.010
# Turn completed in 0.269 seconds
# Linear velocity: 0.544
# Finished at (0.02749, 0.06251)
# Parameters: {0.03888, 0.03888, 0.06500, 0.06042, 0.02518, xxx}
